# %% [markdown]
# # Household Environment (PR2)

# %% [markdown]
# ![image.png](attachment:4fb76f6c-de46-47d4-b50a-90d3f3699494.png)

# %% [markdown]
# ## Run the assembly task
# To see the visualization, open a new launcher tab and open Rvizweb

# %%
;; launch environment and robot
(uiop:run-program "${PWD}/../binder/update_scene.sh household_pr2.launch" :output t)

;; load lisp package
(asdf:load-system :cram-projection-demos)

;; Initialize the plan executive
(roslisp-utilities:startup-ros)

;; Start the task
(demos::assembly-demo)
# Out:
# NIL
# NIL
# 0
# killing /rosout
# killed
# T
# WARNING: System definition file #P"/home/jovyan/workspace/ros/src/cram/cram_3rdparty/cl_store/src/cl-store.asd" contains definition for system "cl-store-tests". Please only define "cl-store" and secondary systems with a name starting with "cl-store/" (e.g. "cl-store/test") in that file.
# WARNING: System definition file #P"/home/jovyan/workspace/ros/src/cram/cram_3rdparty/cl_ppcre/src/cl-ppcre.asd" contains definition for system "cl-ppcre-test". Please only define "cl-ppcre" and secondary systems with a name starting with "cl-ppcre/" (e.g. "cl-ppcre/test") in that file.
# WARNING: System definition file #P"/home/jovyan/workspace/ros/src/cram/cram_3rdparty/split_sequence/src/split-sequence.asd" contains definition for system "split-sequence-tests". Please only define "split-sequence" and secondary systems with a name starting with "split-sequence/" (e.g. "split-sequence/test") in that file.
# WARNING:
#    redefining LISP-UNIT:NUMERICAL-EQUAL (#<STANDARD-CLASS GRID:FOREIGN-ARRAY>
#                                          #<STANDARD-CLASS GRID:FOREIGN-ARRAY>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BIG-KNIFE>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BIG-KNIFE>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BIG-KNIFE>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BIG-KNIFE>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BIG-KNIFE>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BIG-KNIFE>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :BREAD>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-TOP>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                  #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                  #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :WEISSWURST>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                            #<SB-MOP:EQL-SPECIALIZER :RIGHT-HOLD>
#                                                                                            #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# WARNING:
#    Normalized rotation component to #<QUATERNION (0.7071067811865475d0 0.7071067811865475d0 0.0d0 0.0d0)>
# WARNING: redefining CRAM-PROJECTION-DEMOS::FINALIZE in DEFUN
# NIL
# interrupt: Execution interrupted
# [(ROSLISP TOP) INFO] 1752588024.944: Node name is /cram_hl_925379_1752588024
# [(ROSLISP TOP) INFO] 1752588024.945: Namespace is /
# [(ROSLISP TOP) INFO] 1752588024.945: Params are NIL
# [(ROSLISP TOP) INFO] 1752588024.945: Remappings are:
# [(ROSLISP TOP) INFO] 1752588024.945: master URI is 127.0.0.1:11311
# [(ROSLISP TOP) INFO] 1752588029.167: Node startup complete
# [(ROSNODE) INFO] 1752588029.174: ROS init #<FUNCTION CRAM-TF::INIT-TF>.
# [(CRAM-TF INIT-TF) INFO] 1752588029.174: Set *fixed-frame* to "map".
# [(CRAM-TF INIT-TF) INFO] 1752588029.208: Environment name is IAI-KITCHEN.
# [(CRAM-TF INIT-TF) INFO] 1752588029.213: Initialized *transformer* to a TRANSFORM-LISTENER.
# [(CRAM-TF INIT-TF) INFO] 1752588029.213: *tf-default-timeout* is 4.0.
# [(CRAM-TF INIT-TF) INFO] 1752588029.234: Robot name is PR2.
# [(CRAM-TF INIT-TF) INFO] 1752588029.240: Set *ODOM-FRAME* to "odom_combined".
# [(CRAM-TF INIT-TF) INFO] 1752588029.241: Set *ROBOT-BASE-FRAME* to "base_footprint".
# [(CRAM-TF INIT-TF) INFO] 1752588029.241: Set *ROBOT-TORSO-FRAME* to "torso_lift_link".
# [(CRAM-TF INIT-TF) INFO] 1752588029.241: Set *ROBOT-TORSO-JOINT* to "torso_lift_joint".
# [(CRAM-TF INIT-TF) INFO] 1752588029.241: Set *ROBOT-LEFT-TOOL-FRAME* to "l_gripper_tool_frame".
# [(CRAM-TF INIT-TF) INFO] 1752588029.241: Set *ROBOT-RIGHT-TOOL-FRAME* to "r_gripper_tool_frame".
# [(ROSNODE) INFO] 1752588029.241: ROS init #<FUNCTION CRAM-TF::INIT-TF-BROADCASTER>.
# [(ROSNODE) INFO] 1752588029.243: ROS init #<FUNCTION CRAM-TF::INIT-MARKER-PUBLISHER>.
# [(ROSNODE) INFO] 1752588029.243: ROS init #<FUNCTION CRAM-LOCATION-COSTMAP::LOCATION-COSTMAP-VIS-INIT>.
# [(ROSNODE) INFO] 1752588029.245: ROS init #<FUNCTION CRAM-BULLET-REASONING-BELIEF-STATE::ROS-TIME-INIT>.
# [(ROSNODE) INFO] 1752588029.245: ROS init #<FUNCTION CRAM-PROJECTION-DEMOS::INIT-PROJECTION>.
# [(SET-ROBOT-STATE-FROM-TF) WARN] 1752588041.939: Failed with transform-stamped-error:
#     No transform was published between frames base_footprint and map
#     Ignore this warning if no real robot is running.

# %% [markdown]
# ## Write your own task
