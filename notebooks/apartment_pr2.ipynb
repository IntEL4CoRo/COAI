# %% [markdown]
# # Apartment environment (PR2)
# ![image.png](attachment:a421fbf1-0f3c-4a06-bfba-9219e6704e23.png)

# %% [markdown]
# ## Execute the "setting table" task
#
# To see the visualization, open a new launcher tab and open Rvizweb
#
# Details of the task planning see: [apartment-demo.lisp](../ROS_WS/src/cram/cram_demos/cram_projection_demos/src/apartment-demo.lisp)

# %%
(jupyter:clear :wait)(jupyter:markdown "# Initialising the simulation environment ... ![](./loading.gif)")
(uiop:run-program "${HOME}/.binder/update_scene.sh apartment_pr2.launch" :output t)

(jupyter:clear :wait)(jupyter:markdown "# Loading Packages ... ![](./loading.gif)")
(asdf:load-system :cram-projection-demos)

(jupyter:clear :wait)(jupyter:markdown "# Starting ROS nodes ... ![](./loading.gif)")
(roslisp-utilities:startup-ros)

(jupyter:clear :wait)(jupyter:markdown "# Executing task plan ... ![](./loading.gif)")
(demos::apartment-demo)
(jupyter:clear :wait)(jupyter:markdown "# Task completed.")

# %% [markdown]
# ## Write your own task
