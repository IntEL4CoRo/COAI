# %% [markdown]
# # Household Environment (PR2)
# ![image.png](attachment:48936d81-138a-4e7a-bf62-d1df76a2ce65.png)

# %% [markdown]
# ## Run the household setting table task
# To see the visualization, open a new launcher tab and open Rvizweb.
# Details of the task planning see: [household-demo.lisp](../ROS_WS/src/cram/cram_demos/cram_projection_demos/src/household-demo.lisp)

# %%
(load "loading.lisp")

(loading "Initialising the simulation environment ...")
(uiop:run-program "${PWD}/../binder/update_scene.sh household_pr2.launch" :output t)

(loading "Loading CRAM Packages ...")
(asdf:load-system :cram-projection-demos)

(loading "Starting ROS nodes ...")
(roslisp-utilities:startup-ros)

(loading "Executing task plan ...")
(demos::household-demo)
(jupyter:clear :wait)(jupyter:markdown "# Task completed.")

# %% [markdown]
# ## Write your own task
