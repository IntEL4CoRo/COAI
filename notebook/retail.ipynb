# %% [markdown]
# # Retail Environment

# %% [markdown]
# ![retail_banner.png](attachment:c3017af5-cc19-4574-a39c-8d77d16f30c9.png)

# %% [markdown]
# ## Select a robot

# %%
"Select a rotbot!"
(jw:make-button :description "PR2" :on-click (list (lambda (w) w (uiop:run-program "${REPO_DIR}/binder/update_scene.sh retail_pr2.launch" :output t))))
(jw:make-button :description "Donbot" :on-click (list (lambda (w) w (uiop:run-program "${REPO_DIR}/binder/update_scene.sh retail_donbot.launch" :output t))))

# %% [markdown]
# ## Run the retail task
#
# 1. Load the code for the task

# %%
(asdf:load-system :cram-projection-demos)

# %% [markdown]
# 2. Initialize the plan executive

# %%
(roslisp-utilities:startup-ros)

# %% [markdown]
# 3. Start the task

# %%
(demos:retail-demo)

# %% [markdown]
# To stop the task, hit the black square in the top bar.
#
# Change the robot by stopping the launchfile in the terminal with CTRL-C and starting a different launch file. Then execute steps 2 and 3 again.
#
# Source file [retail-demo](../../workspace/ros/src/cram/cram_demos/cram_projection_demos/src/retail-demo.lisp)
