# %% [markdown]
# # Household Environment

# %% [markdown]
# ![household_banner_slim.png](attachment:f4118b31-2eb7-4e32-9eb8-8329e5873a4e.png)

# %% [markdown]
# ## Select a robot

# %%
"Select a rotbot!"
(jw:make-button :description "Tiago" :on-click (list (lambda (w) w (uiop:run-program "${REPO_DIR}/binder/update_scene.sh household_tiago.launch" :output t))))
(jw:make-button :description "PR2" :on-click (list (lambda (w) w (uiop:run-program "${REPO_DIR}/binder/update_scene.sh household_pr2.launch" :output t))))
(jw:make-button :description "Donbot" :on-click (list (lambda (w) w (uiop:run-program "${REPO_DIR}/binder/update_scene.sh household_donbot.launch" :output t))))

# %% [markdown]
# ## Run the household task
#
# 1. Load the code for the task

# %%
(asdf:load-system :cram-projection-demos)

# %% [markdown]
# 2. Initialize the plan executive

# %%
(roslisp-utilities:startup-ros)

# %% [markdown]
# 3. Start the task

# %%
(demos:household-demo)

# %% [markdown]
# To stop the task, hit the black square in the top bar.
#
# Change the robot by stopping the launchfile in the terminal with CTRL-C and starting a different launch file. Then execute steps 2 and 3 again.
#
# Source file [household-demo](../../workspace/ros/src/cram/cram_demos/cram_projection_demos/src/household-demo.lisp)
